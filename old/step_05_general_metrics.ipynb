# %%
from techminer2.metrics import general_metrics

info = general_metrics(
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    # year_filter=(2014, 2024),
    year_filter=(None, None),
    cited_by_filter=(None, None),
    # document_type=[
    #     "Editorial",
    #     #         'Retracted',
    #     #         'Erratum',
    #     "Book chapter",
    #     "Review",
    #     "Conference paper",
    #     "Conference review",
    #     "Book",
    #     "Article",
    # ],
)

print(info.prompt_)
# Out:
# Your task is to generate a short summary for a research paper of a table \
# with record and field statistics for a dataset of scientific \
# publications. The table below, delimited by triple backticks, provides \
# data on the main characteristics of the records and fields of the \
# bibliographic dataset. Use the the information in the table to draw \
# conclusions. Limit your description to one paragraph in at most 100 \
# words.
#
# Table:
# ```
# |                                                        | Value     |
# |:-------------------------------------------------------|:----------|
# | ('GENERAL', 'Timespan')                                | 1996:2024 |
# | ('GENERAL', 'Documents')                               | 1156      |
# | ('GENERAL', 'Annual growth rate %')                    | 27.53     |
# | ('GENERAL', 'Document average age')                    | 11.84     |
# | ('GENERAL', 'Average citations per document')          | 14.71     |
# | ('GENERAL', 'Average citations per document per year') | 0.51      |
# | ('GENERAL', 'Sources')                                 | 607       |
# | ('GENERAL', 'Average documents per source')            | 1.9       |
# | ('DOCUMENT TYPES', 'Article')                          | 475       |
# | ('DOCUMENT TYPES', 'Book')                             | 2         |
# | ('DOCUMENT TYPES', 'Book chapter')                     | 43        |
# | ('DOCUMENT TYPES', 'Conference paper')                 | 583       |
# | ('DOCUMENT TYPES', 'Conference review')                | 26        |
# | ('DOCUMENT TYPES', 'Editorial')                        | 3         |
# | ('DOCUMENT TYPES', 'Erratum')                          | 2         |
# | ('DOCUMENT TYPES', 'Retracted')                        | 4         |
# | ('DOCUMENT TYPES', 'Review')                           | 18        |
# | ('AUTHORS', 'Authors')                                 | 2297      |
# | ('AUTHORS', 'Authors of single-authored documents')    | 76        |
# | ('AUTHORS', 'Single-authored documents')               | 99        |
# | ('AUTHORS', 'Multi-authored documents')                | 1031      |
# | ('AUTHORS', 'Authors per document')                    | 2.99      |
# | ('AUTHORS', 'Co-authors per document')                 | 3.26      |
# | ('AUTHORS', 'International co-authorship %')           | 20.79     |
# | ('AUTHORS', 'Author appearances')                      | 3453      |
# | ('AUTHORS', 'Documents per author')                    | 0.33      |
# | ('AUTHORS', 'Collaboration index')                     | 1.0       |
# | ('AUTHORS', 'Organizations')                           | 1250      |
# | ('AUTHORS', 'Organizations (1st author)')              | 702       |
# | ('AUTHORS', 'Countries')                               | 63        |
# | ('AUTHORS', 'Countries (1st author)')                  | 55        |
# | ('KEYWORDS', 'Raw author keywords')                    | 2206      |
# | ('KEYWORDS', 'Cleaned author keywords')                | 1883      |
# | ('KEYWORDS', 'Raw index keywords')                     | 4953      |
# | ('KEYWORDS', 'Cleaned index keywords')                 | 4166      |
# | ('KEYWORDS', 'Raw keywords')                           | 5963      |
# | ('KEYWORDS', 'Cleaned keywords')                       | 4750      |
# | ('NLP PHRASES', 'Raw title NLP phrases')               | 1190      |
# | ('NLP PHRASES', 'Cleaned title NLP phrases')           | 1068      |
# | ('NLP PHRASES', 'Raw abstract NLP phrases')            | 13668     |
# | ('NLP PHRASES', 'Cleaned abstract NLP phrases')        | 10272     |
# | ('NLP PHRASES', 'Raw NLP phrases')                     | 14222     |
# | ('NLP PHRASES', 'Cleaned NLP phrases')                 | 10683     |
# | ('DESCRIPTORS', 'Raw descriptors')                     | 18493     |
# | ('DESCRIPTORS', 'Cleaned descriptors')                 | 13174     |
# ```
