# %% [markdown]
# ---

# %%
from techminer2.tools import coverage

coverage(
    field="descriptors",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2014, 2024),
    cited_by_filter=(None, None),
    document_type=[
        "Editorial",
        #         'Retracted',
        #         'Erratum',
        "Book chapter",
        "Review",
        "Conference paper",
        "Conference review",
        "Book",
        "Article",
    ],
).tail(20)
# Out:
# --INFO-- Number of documents : 443
# --INFO--   Documents with NA : 0
# --INFO--  Efective documents : 443
#     min_occ  cum_sum_documents  coverage  cum num items
# 8        20                225   50.79 %             10
# 9        19                241   54.40 %             12
# 10       18                258   58.24 %             15
# 11       17                265   59.82 %             17
# 12       16                278   62.75 %             18
# 13       15                284   64.11 %             19
# 14       14                291   65.69 %             21
# 15       13                305   68.85 %             27
# 16       12                322   72.69 %             33
# 17       11                343   77.43 %             41
# 18       10                360   81.26 %             52
# 19        9                386   87.13 %             73
# 20        8                407   91.87 %            100
# 21        7                417   94.13 %            126
# 22        6                429   96.84 %            174
# 23        5                434   97.97 %            230
# 24        4                437   98.65 %            354
# 25        3                440   99.32 %            618
# 26        2                442   99.77 %           1304
# 27        1                443  100.00 %           7225

# %% [markdown]
# ---

# %%
from techminer2.refine.thesaurus.descriptors import find_string

find_string(
    #
    # SEARCH PARAMS:
    contains=[
        "INVENTORY_CONTROL",
        "INVENTORY_MANAGEMENT",
    ],
    startswith=None,
    endswith=None,
)
# Out:
# --INFO-- The file ./thesauri/descriptors.the.txt has been reordered.

# %%
import pandas as pd

pd.set_option("display.max_rows", 100)
from techminer2.science_mapping.co_occurrence import communities
from techminer2.refine.thesaurus.descriptors import apply_thesaurus
from techminer2.refine.thesaurus.descriptors import list_cleanup
from techminer2.refine.thesaurus.descriptors import check_integrity

list_cleanup(root_dir="./")
check_integrity(root_dir="./")
apply_thesaurus(root_dir="./")

communities(
    #
    # COLUMN PARAMS:
    field="descriptors",
    top_n=None,
    occ_range=(7, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2014, 2024),
    cited_by_filter=(None, None),
    document_type=[
        "Editorial",
        #         'Retracted',
        #         'Erratum',
        "Book chapter",
        "Review",
        "Conference paper",
        "Conference review",
        "Book",
        "Article",
    ],
).head(10)
# Out:
# --INFO-- Checking `descriptors.the.txt` integrity.
# --INFO-- Applying `descriptors.the.txt` thesaurus to author/index keywords and abstract/title words
#                              CL_0                                   CL_1  \
# 0          DECISION_MAKING 70:524          REINFORCEMENT_LEARNING 43:297
# 1       INTELLIGENT_AGENTS 55:629            INVENTORY_MANAGEMENT 24:278
# 2  ARTIFICIAL_INTELLIGENCE 37:363                LEARNING_SYSTEMS 22:277
# 3  DECISION_SUPPORT_SYSTEM 31:526  HEURISTICS_AND_META_HEURISTICS 22:189
# 4       INFORMATION_SYSTEM 19:294         VEHICLE_ROUTING_PROBLEM 18:239
# 5   CYBER_PHYSICAL_SYSTEMS 18:286           COMPUTATIONAL_METHODS 13:064
# 6                 PLANNING 15:178                   DEEP_LEARNING 13:049
# 7       INTERNET_OF_THINGS 14:200                        VEHICLES 12:158
# 8         MACHINE_LEARNING 13:110     DEEP_REINFORCEMENT_LEARNING 12:048
# 9         EMBEDDED_SYSTEMS 12:266             LEARNING_ALGORITHMS 11:124
#
#                            CL_2                              CL_3  \
# 0           OPTIMIZATION 32:273    SUSTAINABLE_DEVELOPMENT 17:427
# 1             SCHEDULING 28:328           BULLWHIP_EFFECTS 16:490
# 2            COMPETITION 22:264                GAME_THEORY 14:077
# 3     PRODUCTION_CONTROL 13:138            SYSTEM_DYNAMICS 12:106
# 4           COORDINATION 11:033             SUSTAINABILITY 09:321
# 5      GENETIC_ALGORITHM 10:055  INFORMATION_DISSEMINATION 09:305
# 6    INTEGER_PROGRAMMING 09:126        SHARING_INFORMATION 09:154
# 7  PRODUCTION_SCHEDULING 09:114                UNCERTAINTY 09:012
# 8         TRANSPORTATION 08:141       ENVIRONMENTAL_IMPACT 08:105
# 9    MATHEMATICAL_MODELS 08:083           EVENT_SIMULATORS 08:085
#
#                             CL_4
# 0       NEGOTIATION_MODEL 13:164
# 1                  DEMAND 12:038
# 2             NEGOTIATION 10:157
# 3  NEGOTIATION_STRATEGIES 09:099
# 4  NEGOTIATION_MECHANISMS 09:066
# 5     NEGOTIATION_PROCESS 07:077
# 6      PROJECT_MANAGEMENT 07:056
# 7
# 8
# 9

# %%
from techminer2.refine.thesaurus.descriptors import list_cleanup, replace_string

replace_string(
    #
    # SEARCH PARAMS
    contains="INVENTORY_CONTROL",
    startswith=None,
    endswith=None,
    #
    # REPLACE PARAMS:
    replace_by="INVENTORY_MANAGEMENT",
)

list_cleanup()
# Out:
# --INFO-- The file ./thesauri/descriptors.the.txt has been processed.

# %%
from techminer2.search import concordances

print(
    concordances(
        #
        # FUNCTION PARAMS:
        search_for="CHATBOT_S",
        top_n=30,
        report_file="concordances_report.txt",
        prompt_file="concordances_prompt.txt",
        #
        # DATABASE PARAMS:
        root_dir="./",
        database="main",
        year_filter=(None, None),
        cited_by_filter=(None, None),
    ).contexts_
)

# %% [markdown]
# ---

# %%
from techminer2.science_mapping.co_occurrence import communities_summary

m = communities_summary(
    field="descriptors",
    conserve_counters=False,
    top_n=None,
    occ_range=(7, None),
    algorithm_or_dict="louvain",
    association_index="association",
    root_dir="./",
    year_filter=(2014, 2024),
    document_type=[
        "Editorial",
        #         'Retracted',
        #         'Erratum',
        "Book chapter",
        "Review",
        "Conference paper",
        "Conference review",
        "Book",
        "Article",
    ],
)

m["Terms"] = m["Terms"].str.split("; ")
m["Terms"] = m["Terms"].map(
    lambda x: [t.strip().replace("_", " ").title() for t in x[:10]]
)
m["Terms"] = m["Terms"].str.join("; ")
m.to_csv("reports/clusters_summary.csv", sep="\t")
print(m.to_markdown())
# Out:
# |    | Cluster   |   Num Terms |   Percentage | Terms                                                                                                                                                                                                                     |
# |---:|:----------|------------:|-------------:|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | CL_0      |          39 |         42.4 | Decision Making; Intelligent Agents; Artificial Intelligence; Decision Support System; Information System; Cyber Physical Systems; Planning; Internet Of Things; Machine Learning; Embedded Systems                       |
# |  1 | CL_1      |          16 |         17.4 | Reinforcement Learning; Inventory Management; Learning Systems; Heuristics And Meta Heuristics; Vehicle Routing Problem; Computational Methods; Deep Learning; Vehicles; Deep Reinforcement Learning; Learning Algorithms |
# |  2 | CL_2      |          15 |         16.3 | Optimization; Scheduling; Competition; Production Control; Coordination; Genetic Algorithm; Integer Programming; Production Scheduling; Transportation; Mathematical Models                                               |
# |  3 | CL_3      |          15 |         16.3 | Sustainable Development; Bullwhip Effects; Game Theory; System Dynamics; Sustainability; Information Dissemination; Sharing Information; Uncertainty; Environmental Impact; Event Simulators                              |
# |  4 | CL_4      |           7 |          7.6 | Negotiation Model; Demand; Negotiation; Negotiation Strategies; Negotiation Mechanisms; Negotiation Process; Project Management                                                                                           |

# %% [markdown]
# ---

# %%
from techminer2.science_mapping.co_occurrence import report

report(
    field="descriptors",
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(7, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2014, 2024),
    cited_by_filter=(None, None),
    document_type=[
        "Editorial",
        #         'Retracted',
        #         'Erratum',
        "Book chapter",
        "Review",
        "Conference paper",
        "Conference review",
        "Book",
        "Article",
    ],
)
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap', 'graph_tool', 'bayanpy'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap'}
# --INFO-- The file './reports/co_occurrence/CL_0_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_1_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_2_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_3_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_4_relationships_prompt.txt' was created.
# mv: rename reports/co_occurrence/network/ to reports/clusters: No such file or directory
